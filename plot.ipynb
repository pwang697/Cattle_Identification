# %%
import matplotlib.pyplot as plt
# 90-10
x_axis = ['top1','top2','top3','top4']
y_ViT = [0.9147, 0.9887, 0.9987, 1.0000]
y_Resnet34 = [0.8913, 0.9753, 0.9947, 1.0000]
y_Resnet50 = [0.7600, 0.8967, 0.9687, 0.9933]
y_Resnet101 = [0.6493, 0.8487, 0.9513, 0.9920]

plt.plot(list(range(4)),y_ViT, color = 'red')
plt.plot(list(range(4)),y_Resnet34, color = 'blue')
plt.plot(list(range(4)),y_Resnet50, color = 'green')
plt.plot(list(range(4)),y_Resnet101, color = 'grey')
plt.xticks(list(range(4)), x_axis)
plt.legend(labels = ['ViT', 'Resnet34', 'Resnet50', 'Resnet101'], loc = 'lower right')
plt.title('Dataset: 90% known, 10% unknown')
plt.show()

# %%
# 70-30
x_axis = ['top1','top2','top3','top4']
y_ViT = [0.8213, 0.9560, 0.9940, 0.9993]
y_Resnet34 = [0.8587, 0.9673, 0.9927, 1.0000]
y_Resnet50 = [0.6973, 0.8960, 0.9680, 0.9953]
y_Resnet101 = [0.6473, 0.8680, 0.9560, 0.9920]

plt.plot(list(range(4)),y_ViT, color = 'red')
plt.plot(list(range(4)),y_Resnet34, color = 'blue')
plt.plot(list(range(4)),y_Resnet50, color = 'green')
plt.plot(list(range(4)),y_Resnet101, color = 'grey')
plt.xticks(list(range(4)), x_axis)
plt.legend(labels = ['ViT', 'Resnet34', 'Resnet50', 'Resnet101'], loc = 'lower right')
plt.title('Dataset: 70% known, 30% unknown')
plt.show()

# %%
# 50-50
x_axis = ['top1','top2','top3','top4']
y_ViT = [0.7833, 0.9473, 0.9887, 0.9993]
y_Resnet34 = [0.8080, 0.9413, 0.9833, 0.9953]
y_Resnet50 = [0.6967, 0.8993, 0.9713, 0.9933]
y_Resnet101 = [0.5800, 0.8173, 0.9373, 0.9887]

plt.plot(list(range(4)),y_ViT, color = 'red')
plt.plot(list(range(4)),y_Resnet34, color = 'blue')
plt.plot(list(range(4)),y_Resnet50, color = 'green')
plt.plot(list(range(4)),y_Resnet101, color = 'grey')
plt.xticks(list(range(4)), x_axis)
plt.legend(labels = ['ViT', 'Resnet34', 'Resnet50', 'Resnet101'], loc = 'lower right')
plt.title('Dataset: 50% known, 50% unknown')
plt.show()

# %%
# 30-70
x_axis = ['top1','top2','top3','top4']
y_ViT = [0.7927, 0.9473, 0.9907, 0.9993]
y_Resnet34 = [0.7093, 0.8987, 0.9700, 0.9947]
y_Resnet50 = [0.5980, 0.8320, 0.9347, 0.9887]
y_Resnet101 = [0.4860, 0.6973, 0.8327, 0.9347]

plt.plot(list(range(4)),y_ViT, color = 'red')
plt.plot(list(range(4)),y_Resnet34, color = 'blue')
plt.plot(list(range(4)),y_Resnet50, color = 'green')
plt.plot(list(range(4)),y_Resnet101, color = 'grey')
plt.xticks(list(range(4)), x_axis)
plt.legend(labels = ['ViT', 'Resnet34', 'Resnet50', 'Resnet101'], loc = 'lower right')
plt.title('Dataset: 30% known, 70% unknown')
plt.show()

# %%
# 10-90
x_axis = ['top1','top2','top3','top4']
y_ViT = [0.7107, 0.8913, 0.9660, 0.9933]
y_Resnet34 = [0.6000, 0.8060, 0.9293, 0.9813]
y_Resnet50 = [0.4993, 0.7167, 0.8587, 0.9487]
y_Resnet101 = [0.5047, 0.7040, 0.8487, 0.9413]

plt.plot(list(range(4)),y_ViT, color = 'red')
plt.plot(list(range(4)),y_Resnet34, color = 'blue')
plt.plot(list(range(4)),y_Resnet50, color = 'green')
plt.plot(list(range(4)),y_Resnet101, color = 'grey')
plt.xticks(list(range(4)), x_axis)
plt.legend(labels = ['ViT', 'Resnet34', 'Resnet50', 'Resnet101'], loc = 'lower right')
plt.title('Dataset: 10% known, 90% unknown')
plt.show()

# %%
# top1
x_axis = ['10%-90%','30%-70%','50%-50%','70%-30%','90%-10%']
y_ViT = [0.7107, 0.7927, 0.7833, 0.8213, 0.9147]
y_Resnet34 = [0.6000, 0.7093, 0.8080, 0.8587, 0.8913]
y_Resnet50 = [0.4993, 0.5980, 0.6967, 0.6973, 0.7600]
y_Resnet101 = [0.5047, 0.4860, 0.5800, 0.6473, 0.6493]

plt.plot(list(range(5)),y_ViT, color = 'red')
plt.plot(list(range(5)),y_Resnet34, color = 'blue')
plt.plot(list(range(5)),y_Resnet50, color = 'green')
plt.plot(list(range(5)),y_Resnet101, color = 'grey')
plt.xticks(list(range(5)), x_axis)
plt.legend(labels = ['ViT', 'Resnet34', 'Resnet50', 'Resnet101'], loc = 'lower right')
plt.title('Top1 accuracy')
plt.show()
